# %%
import os
import pandas as pd
from pandas import DataFrame
from keras.models import Sequential, Model, load_model, Model
from keras.layers import Input, Dense, Activation, Reshape
from keras.layers import Convolution2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
# matplotlib.use("TkAgg")
# %matplotlib inline
import numpy as np
np.random.seed(1)
from sklearn.metrics import confusion_matrix
from PIL import Image
import random
import math

model = Sequential()

model.add(Convolution2D(
    batch_input_shape=(None, 3, 128, 128),
    filters=12,
    kernel_size=3,
    strides=1,
    padding='same',
    data_format='channels_first',
))
model.add(Activation('relu'))

model.add(Convolution2D(
    filters=12, 
    kernel_size=6, 
    strides=1, 
    padding='same', 
    data_format='channels_first'
))
model.add(Activation('relu'))

model.add(Convolution2D(
    filters=24, 
    kernel_size=9, 
    strides=2, 
    padding='same', 
    data_format='channels_first'
))
model.add(Activation('selu'))

model.add(Convolution2D(
    filters=1, 
    kernel_size=1, 
    strides=1, 
    padding='same', 
    data_format='channels_first'
))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation('sigmoid'))

model.add(Dense(8))
model.add(Activation('softmax'))

model.summary()
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W1109 12:19:48.008368 4710915520 deprecation_wrapper.py:119] From /Users/ianfan/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1109 12:19:48.023311 4710915520 deprecation_wrapper.py:119] From /Users/ianfan/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1109 12:19:48.026206 4710915520 deprecation_wrapper.py:119] From /Users/ianfan/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1109 12:19:48.040377 4710915520 deprecation_wrapper.py:119] From /Users/ianfan/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1109 12:19:48.041093 4710915520 deprecation_wrapper.py:119] From /Users/ianfan/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1109 12:19:48.087090 4710915520 deprecation.py:323] From /Users/ianfan/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3217: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 12, 128, 128)      336
# _________________________________________________________________
# activation_1 (Activation)    (None, 12, 128, 128)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 128, 128)      5196
# _________________________________________________________________
# activation_2 (Activation)    (None, 12, 128, 128)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 64, 64)        23352
# _________________________________________________________________
# activation_3 (Activation)    (None, 24, 64, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 64, 64)         25
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               524416
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 1032
# _________________________________________________________________
# activation_5 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 554,357
# Trainable params: 554,357
# Non-trainable params: 0
# _________________________________________________________________
