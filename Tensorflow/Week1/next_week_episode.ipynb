# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)

# %%
x_train = np.linspace(-10, 10, 30)[:, np.newaxis]
noise = np.random.normal(0, 3.0, size=x_data.shape)
y_train = np.power(x_data, 2) + noise
plt.scatter(x_data, y_data, c="blue")
plt.show()

# %%
x = tf.placeholder(tf.float32, [None, 1])
y = tf.placeholder(tf.float32, [None, 1])

'''DNN(Deep Neural Network)'''
# layer1 = tf.layers.dense(inputs=x, units=10, activation=tf.nn.relu)
# predict = tf.layers.dense(layer1, 1)

# layer1 = tf.layers.dense(inputs=x, units=10, activation=tf.nn.relu)
# layer2 = tf.layers.dense(layer1, units=20, activation=tf.nn.relu)
# predict = tf.layers.dense(layer2, 1)

predict = tf.layers.dense(x, 1)

loss = tf.losses.mean_squared_error(labels=y, predictions=predict)
train = tf.train.GradientDescentOptimizer(learning_rate=1e-3).minimize(loss)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(3000):
    c_ , _ = sess.run([loss, train], feed_dict={x:x_train, y:y_train})
    if step%50 == 0:
        print("cost: ", c_)
        x_draw = np.linspace(-12, 12, 100)[:,np.newaxis]
        y_draw = sess.run(predict, feed_dict={x:x_draw})
        plt.cla()
        plt.plot(x_train, y_train, "b^")
        plt.plot(x_draw, y_draw, "r-")
        plt.pause(0.1)
# Out:
# cost:  2315.4673
# cost:  2062.8003
# cost:  1875.3921
# cost:  1721.9979
# cost:  1596.4343
# cost:  1493.6523
# cost:  1409.5184
# cost:  1340.6495
# cost:  1284.275
# cost:  1238.129
# cost:  1200.3556
# cost:  1169.4355
# cost:  1144.1251
# cost:  1123.4071
# cost:  1106.4479
# cost:  1092.5659
# cost:  1081.2024
# cost:  1071.9006
# cost:  1064.2865
# cost:  1058.0538
# cost:  1052.952
# cost:  1048.7758
# cost:  1045.3573
# cost:  1042.559
# cost:  1040.2683
# cost:  1038.3933
# cost:  1036.8585
# cost:  1035.6022
# cost:  1034.5737
# cost:  1033.7319
# cost:  1033.0428
# cost:  1032.4789
# cost:  1032.0171
# cost:  1031.6392
# cost:  1031.3298
# cost:  1031.0765
# cost:  1030.8694
# cost:  1030.6996
# cost:  1030.5607
# cost:  1030.447
# cost:  1030.354
# cost:  1030.2777
# cost:  1030.2155
# cost:  1030.1643
# cost:  1030.1226
# cost:  1030.0884
# cost:  1030.0603
# cost:  1030.0375
# cost:  1030.0187
# cost:  1030.0033
# cost:  1029.9907
# cost:  1029.9803
# cost:  1029.972
# cost:  1029.9651
# cost:  1029.9595
# cost:  1029.9548
# cost:  1029.951
# cost:  1029.948
# cost:  1029.9456
# cost:  1029.9435

# %%
x_new = [[1.2]]
y_new = sess.run(predict, feed_dict={x:x_new})
plt.cla()
plt.plot(x_train, y_train, "b^")
plt.plot(x_new, y_new, "r^")
